# %% [markdown]
# <a href="https://colab.research.google.com/github/agusekominarno/imageretrieval/blob/main/histogram/hi_histogram_equalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://riset.informatika.umm.ac.id/aguseko/dog.png --no-check-certificate
# Out:
# --2021-10-06 11:28:40--  https://riset.informatika.umm.ac.id/aguseko/dog.png
# Resolving riset.informatika.umm.ac.id (riset.informatika.umm.ac.id)... 202.52.52.30
# Connecting to riset.informatika.umm.ac.id (riset.informatika.umm.ac.id)|202.52.52.30|:443... connected.
# WARNING: cannot verify riset.informatika.umm.ac.id's certificate, issued by ‘CN=Sectigo RSA Domain Validation Secure Server CA,O=Sectigo Limited,L=Salford,ST=Greater Manchester,C=GB’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 129438 (126K) [image/png]
# Saving to: ‘dog.png.3’
#
# dog.png.3           100%[===================>] 126.40K   272KB/s    in 0.5s
#
# 2021-10-06 11:28:42 (272 KB/s) - ‘dog.png.3’ saved [129438/129438]

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import argparse
import cv2

# %%
def plt_imshow(title, image):
    # convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
    "image": "dog.png"
}

# %%
# load the input image from disk and convert it to grayscale
print("[INFO] loading input image...")
image = cv2.imread(args["image"])
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# apply histogram equalization
print("[INFO] performing histogram equalization...")
equalized = cv2.equalizeHist(gray)
# Out:
# [INFO] loading input image...
# [INFO] performing histogram equalization...

# %%
# show the original grayscale image and equalized image
plt_imshow("Input", gray)
plt_imshow("Histogram Equalization", equalized)

# %% [markdown]
# Implementing adaptive histogram equalization with OpenCV

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
    "image": "dog.png",
    "clip": 2.0,
    "tile": 8
}

# %%
# load the input image from disk and convert it to grayscale
print("[INFO] loading input image...")
image = cv2.imread(args["image"])
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
print("[INFO] applying CLAHE...")
clahe = cv2.createCLAHE(clipLimit=args["clip"],
	tileGridSize=(args["tile"], args["tile"]))
equalized = clahe.apply(gray)
# Out:
# [INFO] loading input image...
# [INFO] applying CLAHE...

# %%
# show the original grayscale image and CLAHE output image
plt_imshow("Input", gray)
plt_imshow("CLAHE", equalized)
